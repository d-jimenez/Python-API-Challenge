# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import os
from pprint import pprint

# Import API key - DO NOT PUSH TO GitHub
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities_list = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities_list:
        cities_list.append(city)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#The base URL to access the OpenWeather API Data, remove all data after ?
#api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}
base_url='http://api.openweathermap.org/data/2.5/weather?'

#Add API Key and City Name to Query_URL
city_list_500=[]
lat_500=[]
long_500=[]
max_temp_500=[]
humidity_500=[]
cloudiness_500=[]
wind_speed_500=[]
country_500=[]
date_500=[]
counter=0
group=1

#For loop itterates through list of randomly generated cities, 
#pings the OpenWeather database for each city and appends the cities information to empty lists

for each_city in cities_list:
    try:
        query_url=f'{base_url}q={each_city}&appid={weather_api_key}'
        weather_response=requests.get(query_url)
        weather_data=weather_response.json()
        
        city_list_500.append(weather_data['name'])
        lat_500.append(weather_data['coord']['lat'])
        long_500.append(weather_data['coord']['lon'])
        max_temp_500.append(weather_data['main']['temp_max'])
        humidity_500.append(weather_data['main']['humidity'])
        cloudiness_500.append(weather_data['clouds']['all'])
        wind_speed_500.append(weather_data['wind']['speed'])
        country_500.append(weather_data['sys']['country'])
        date_500.append(weather_data['dt'])
        
        counter+=1
        
        if counter>50:
            counter=1
            group=group+1
        
        print(f'Processing record {counter} of set {group} | {each_city}')
    
    except:
        print('City not found in OpenWeather API.')
# Out:
# Processing record 1 of set 1 | letterkenny
# Processing record 2 of set 1 | kapaa
# Processing record 3 of set 1 | seymchan
# Processing record 4 of set 1 | phan thiet
# Processing record 5 of set 1 | tuatapere
# Processing record 6 of set 1 | jamestown
# Processing record 7 of set 1 | castro
# Processing record 8 of set 1 | klaksvik
# Processing record 9 of set 1 | bengkulu
# Processing record 10 of set 1 | longkou
# Processing record 11 of set 1 | kaitangata
# Processing record 12 of set 1 | albany
# Processing record 13 of set 1 | arraial do cabo
# Processing record 14 of set 1 | souillac
# Processing record 15 of set 1 | busselton
# Processing record 16 of set 1 | wawa
# Processing record 17 of set 1 | puerto ayora
# Processing record 18 of set 1 | hermanus
# Processing record 19 of set 1 | bozhou
# Processing record 20 of set 1 | barrow
# Processing record 21 of set 1 | natal
# Processing record 22 of set 1 | butaritari
# Processing record 23 of set 1 | cape town
# Processing record 24 of set 1 | vardo
# Processing record 25 of set 1 | saskylakh
# Processing record 26 of set 1 | vila franca do campo
# Processing record 27 of set 1 | thinadhoo
# Processing record 28 of set 1 | ushuaia
# Processing record 29 of set 1 | pokhara
# Processing record 30 of set 1 | katangli
# Processing record 31 of set 1 | hobart
# Processing record 32 of set 1 | tvoroyri
# Processing record 33 of set 1 | mataura
# Processing record 34 of set 1 | victoria
# City not found in OpenWeather API.
# Processing record 35 of set 1 | rikitea
# Processing record 36 of set 1 | farmington
# City not found in OpenWeather API.
# Processing record 37 of set 1 | vaini
# Processing record 38 of set 1 | padang
# Processing record 39 of set 1 | pangnirtung
# Processing record 40 of set 1 | tuktoyaktuk
# Processing record 41 of set 1 | torbay
# Processing record 42 of set 1 | ashtian
# Processing record 43 of set 1 | havre-saint-pierre
# Processing record 44 of set 1 | dingle
# Processing record 45 of set 1 | usogorsk
# Processing record 46 of set 1 | guaratinga
# Processing record 47 of set 1 | progreso
# Processing record 48 of set 1 | tiarei
# City not found in OpenWeather API.
# Processing record 49 of set 1 | nikolskoye
# Processing record 50 of set 1 | galesong
# Processing record 1 of set 2 | biak
# Processing record 2 of set 2 | ayan
# Processing record 3 of set 2 | bredasdorp
# Processing record 4 of set 2 | atuona
# Processing record 5 of set 2 | goderich
# Processing record 6 of set 2 | bairiki
# Processing record 7 of set 2 | hithadhoo
# Processing record 8 of set 2 | khatanga
# Processing record 9 of set 2 | aranos
# City not found in OpenWeather API.
# City not found in OpenWeather API.
# City not found in OpenWeather API.
# Processing record 10 of set 2 | tornio
# Processing record 11 of set 2 | tawau
# Processing record 12 of set 2 | mount gambier
# Processing record 13 of set 2 | geraldton
# Processing record 14 of set 2 | punta arenas
# Processing record 15 of set 2 | brae
# Processing record 16 of set 2 | kailua
# Processing record 17 of set 2 | chuy
# Processing record 18 of set 2 | dikson
# Processing record 19 of set 2 | dudinka
# Processing record 20 of set 2 | urusha
# Processing record 21 of set 2 | fare
# Processing record 22 of set 2 | nemuro
# Processing record 23 of set 2 | naberera
# Processing record 24 of set 2 | plettenberg bay
# Processing record 25 of set 2 | chokurdakh
# Processing record 26 of set 2 | grand-santi
# Processing record 27 of set 2 | shache
# Processing record 28 of set 2 | sao joao da barra
# Processing record 29 of set 2 | marsh harbour
# Processing record 30 of set 2 | chara
# Processing record 31 of set 2 | kuching
# Processing record 32 of set 2 | pevek
# Processing record 33 of set 2 | ponta do sol
# Processing record 34 of set 2 | sena madureira
# Processing record 35 of set 2 | kem
# Processing record 36 of set 2 | saint george
# Processing record 37 of set 2 | perevoz
# Processing record 38 of set 2 | santa rosa
# Processing record 39 of set 2 | fortuna
# Processing record 40 of set 2 | luganville
# Processing record 41 of set 2 | kodiak
# Processing record 42 of set 2 | varzea da palma
# City not found in OpenWeather API.
# Processing record 43 of set 2 | sfantu gheorghe
# Processing record 44 of set 2 | namatanai
# Processing record 45 of set 2 | hirara
# Processing record 46 of set 2 | barra dos coqueiros
# Processing record 47 of set 2 | kavaratti
# Processing record 48 of set 2 | tura
# Processing record 49 of set 2 | kenai
# Processing record 50 of set 2 | mahebourg
# Processing record 1 of set 3 | marion
# Processing record 2 of set 3 | carnarvon
# Processing record 3 of set 3 | tasiilaq
# Processing record 4 of set 3 | georgetown
# Processing record 5 of set 3 | qaanaaq
# Processing record 6 of set 3 | general pico
# Processing record 7 of set 3 | port alfred
# Processing record 8 of set 3 | avarua
# Processing record 9 of set 3 | atasu
# Processing record 10 of set 3 | calama
# City not found in OpenWeather API.
# Processing record 11 of set 3 | westport
# Processing record 12 of set 3 | pisco
# Processing record 13 of set 3 | hilo
# Processing record 14 of set 3 | igarka
# Processing record 15 of set 3 | saint-philippe
# Processing record 16 of set 3 | iksha
# City not found in OpenWeather API.
# Processing record 17 of set 3 | new norfolk
# Processing record 18 of set 3 | mar del plata
# Processing record 19 of set 3 | san patricio
# Processing record 20 of set 3 | talcahuano
# Processing record 21 of set 3 | meulaboh
# Processing record 22 of set 3 | urengoy
# Processing record 23 of set 3 | umm lajj
# Processing record 24 of set 3 | guerrero negro
# Processing record 25 of set 3 | ancud
# Processing record 26 of set 3 | ajdabiya
# Processing record 27 of set 3 | port elizabeth
# Processing record 28 of set 3 | mpanda
# Processing record 29 of set 3 | lazaro cardenas
# Processing record 30 of set 3 | bugama
# Processing record 31 of set 3 | dubbo
# Processing record 32 of set 3 | harper
# Processing record 33 of set 3 | iquitos
# Processing record 34 of set 3 | matara
# Processing record 35 of set 3 | fuyu
# City not found in OpenWeather API.
# Processing record 36 of set 3 | takoradi
# Processing record 37 of set 3 | erenhot
# Processing record 38 of set 3 | launceston
# Processing record 39 of set 3 | tyukhtet
# Processing record 40 of set 3 | broken hill
# Processing record 41 of set 3 | mahajanga
# Processing record 42 of set 3 | dhidhdhoo
# Processing record 43 of set 3 | touros
# Processing record 44 of set 3 | nieves
# City not found in OpenWeather API.
# Processing record 45 of set 3 | hervey bay
# Processing record 46 of set 3 | ornskoldsvik
# Processing record 47 of set 3 | la ronge
# Processing record 48 of set 3 | gawler
# Processing record 49 of set 3 | nishihara
# Processing record 50 of set 3 | narsaq
# Processing record 1 of set 4 | ponta delgada
# Processing record 2 of set 4 | longyearbyen
# Processing record 3 of set 4 | husavik
# Processing record 4 of set 4 | nelson bay
# Processing record 5 of set 4 | hue
# City not found in OpenWeather API.
# Processing record 6 of set 4 | olafsvik
# Processing record 7 of set 4 | adrar
# Processing record 8 of set 4 | bluff
# City not found in OpenWeather API.
# Processing record 9 of set 4 | bambous virieux
# Processing record 10 of set 4 | la encarnacion
# Processing record 11 of set 4 | pacific grove
# Processing record 12 of set 4 | kiama
# Processing record 13 of set 4 | teguise
# Processing record 14 of set 4 | domna
# Processing record 15 of set 4 | moyale
# Processing record 16 of set 4 | faanui
# Processing record 17 of set 4 | esperance
# Processing record 18 of set 4 | severo-kurilsk
# Processing record 19 of set 4 | qiongshan
# City not found in OpenWeather API.
# Processing record 20 of set 4 | ribeira grande
# Processing record 21 of set 4 | san jeronimo
# Processing record 22 of set 4 | thompson
# Processing record 23 of set 4 | kloulklubed
# Processing record 24 of set 4 | norman wells
# Processing record 25 of set 4 | riviere-au-renard
# Processing record 26 of set 4 | qui nhon
# Processing record 27 of set 4 | ahuimanu
# Processing record 28 of set 4 | porong
# Processing record 29 of set 4 | teya
# Processing record 30 of set 4 | shelburne
# Processing record 31 of set 4 | graham
# Processing record 32 of set 4 | fairbanks
# Processing record 33 of set 4 | skibbereen
# Processing record 34 of set 4 | tiksi
# Processing record 35 of set 4 | viedma
# Processing record 36 of set 4 | bukama
# Processing record 37 of set 4 | beringovskiy
# Processing record 38 of set 4 | cidreira
# Processing record 39 of set 4 | tuy hoa
# City not found in OpenWeather API.
# Processing record 40 of set 4 | jasper
# Processing record 41 of set 4 | coahuayana
# Processing record 42 of set 4 | porangatu
# Processing record 43 of set 4 | dunedin
# City not found in OpenWeather API.
# Processing record 44 of set 4 | waipawa
# Processing record 45 of set 4 | chiplun
# City not found in OpenWeather API.
# Processing record 46 of set 4 | jardim
# Processing record 47 of set 4 | hilton head island
# Processing record 48 of set 4 | srednekolymsk
# Processing record 49 of set 4 | ngunguru
# Processing record 50 of set 4 | peniche
# Processing record 1 of set 5 | kenora
# Processing record 2 of set 5 | sola
# Processing record 3 of set 5 | moree
# City not found in OpenWeather API.
# City not found in OpenWeather API.
# Processing record 4 of set 5 | zarubino
# Processing record 5 of set 5 | yenagoa
# Processing record 6 of set 5 | narrabri
# Processing record 7 of set 5 | grindavik
# Processing record 8 of set 5 | aksarka
# Processing record 9 of set 5 | prachuap khiri khan
# Processing record 10 of set 5 | entre rios
# Processing record 11 of set 5 | wright
# Processing record 12 of set 5 | marinette
# Processing record 13 of set 5 | lompoc
# Processing record 14 of set 5 | bolshevik
# City not found in OpenWeather API.
# Processing record 15 of set 5 | lovozero
# Processing record 16 of set 5 | udachnyy
# Processing record 17 of set 5 | minab
# Processing record 18 of set 5 | morondava
# Processing record 19 of set 5 | salalah
# Processing record 20 of set 5 | whangarei
# Processing record 21 of set 5 | naples
# Processing record 22 of set 5 | muros
# Processing record 23 of set 5 | koumac
# Processing record 24 of set 5 | clyde river
# Processing record 25 of set 5 | yulara
# Processing record 26 of set 5 | piacabucu
# Processing record 27 of set 5 | dong hoi
# Processing record 28 of set 5 | lebu
# City not found in OpenWeather API.
# Processing record 29 of set 5 | te anau
# Processing record 30 of set 5 | bima
# Processing record 31 of set 5 | shilovo
# Processing record 32 of set 5 | trairi
# Processing record 33 of set 5 | kungurtug
# Processing record 34 of set 5 | havelock
# Processing record 35 of set 5 | hasaki
# Processing record 36 of set 5 | darasun
# Processing record 37 of set 5 | veraval
# Processing record 38 of set 5 | hobyo
# Processing record 39 of set 5 | male
# Processing record 40 of set 5 | guangyuan
# Processing record 41 of set 5 | oranjemund
# Processing record 42 of set 5 | harrisonville
# Processing record 43 of set 5 | callaway
# Processing record 44 of set 5 | kruisfontein
# Processing record 45 of set 5 | marawi
# Processing record 46 of set 5 | isangel
# Processing record 47 of set 5 | provideniya
# Processing record 48 of set 5 | itapetininga
# City not found in OpenWeather API.
# Processing record 49 of set 5 | sisimiut
# Processing record 50 of set 5 | alice springs
# Processing record 1 of set 6 | glinka
# Processing record 2 of set 6 | cherskiy
# Processing record 3 of set 6 | alekseyevsk
# Processing record 4 of set 6 | pecos
# Processing record 5 of set 6 | chapais
# City not found in OpenWeather API.
# Processing record 6 of set 6 | port-cartier
# Processing record 7 of set 6 | arenal
# Processing record 8 of set 6 | hamilton
# Processing record 9 of set 6 | tazovskiy
# Processing record 10 of set 6 | broome
# Processing record 11 of set 6 | tirat karmel
# Processing record 12 of set 6 | floriano
# Processing record 13 of set 6 | zhigansk
# Processing record 14 of set 6 | mana
# City not found in OpenWeather API.
# Processing record 15 of set 6 | belyy yar
# Processing record 16 of set 6 | saldanha
# City not found in OpenWeather API.
# Processing record 17 of set 6 | sitka
# Processing record 18 of set 6 | joshimath
# Processing record 19 of set 6 | consett
# City not found in OpenWeather API.
# Processing record 20 of set 6 | corrente
# Processing record 21 of set 6 | zabaykalsk
# Processing record 22 of set 6 | abaete
# Processing record 23 of set 6 | tautira
# Processing record 24 of set 6 | malpe
# City not found in OpenWeather API.
# Processing record 25 of set 6 | maizuru
# Processing record 26 of set 6 | jilib
# Processing record 27 of set 6 | constitucion
# Processing record 28 of set 6 | ambilobe
# Processing record 29 of set 6 | komsomolskiy
# Processing record 30 of set 6 | usagara
# Processing record 31 of set 6 | yukhnov
# Processing record 32 of set 6 | mandalgovi
# Processing record 33 of set 6 | caravelas
# Processing record 34 of set 6 | college
# Processing record 35 of set 6 | leningradskiy
# Processing record 36 of set 6 | east london
# Processing record 37 of set 6 | port augusta
# Processing record 38 of set 6 | nantucket
# Processing record 39 of set 6 | lyubymivka
# Processing record 40 of set 6 | pangai
# Processing record 41 of set 6 | turkistan
# Processing record 42 of set 6 | lavrentiya
# Processing record 43 of set 6 | marienburg
# Processing record 44 of set 6 | manado
# Processing record 45 of set 6 | port-gentil
# Processing record 46 of set 6 | gizo
# Processing record 47 of set 6 | cabedelo
# Processing record 48 of set 6 | burriana
# Processing record 49 of set 6 | manono
# Processing record 50 of set 6 | usinsk
# Processing record 1 of set 7 | maragogi
# Processing record 2 of set 7 | cassilandia
# Processing record 3 of set 7 | decatur
# Processing record 4 of set 7 | berea
# Processing record 5 of set 7 | garachine
# Processing record 6 of set 7 | san luis
# Processing record 7 of set 7 | kalmunai
# Processing record 8 of set 7 | mawlaik
# Processing record 9 of set 7 | mitsamiouli
# Processing record 10 of set 7 | yatou
# Processing record 11 of set 7 | valera
# Processing record 12 of set 7 | iramuco
# Processing record 13 of set 7 | uyemskiy
# Processing record 14 of set 7 | warri
# Processing record 15 of set 7 | pahrump
# Processing record 16 of set 7 | codrington
# City not found in OpenWeather API.
# Processing record 17 of set 7 | nanortalik
# Processing record 18 of set 7 | milwaukee
# Processing record 19 of set 7 | aksha
# Processing record 20 of set 7 | port lincoln
# Processing record 21 of set 7 | orda
# Processing record 22 of set 7 | okhotsk
# City not found in OpenWeather API.
# Processing record 23 of set 7 | kaili
# Processing record 24 of set 7 | mezen
# Processing record 25 of set 7 | upernavik
# Processing record 26 of set 7 | omidiyeh
# Processing record 27 of set 7 | naze
# Processing record 28 of set 7 | artyom
# Processing record 29 of set 7 | cairns
# Processing record 30 of set 7 | umtata
# Processing record 31 of set 7 | falam
# Processing record 32 of set 7 | dutlwe
# City not found in OpenWeather API.
# Processing record 33 of set 7 | devils lake
# Processing record 34 of set 7 | saint-felicien
# City not found in OpenWeather API.
# Processing record 35 of set 7 | quebo
# Processing record 36 of set 7 | bethel
# Processing record 37 of set 7 | erzin
# Processing record 38 of set 7 | kutum
# Processing record 39 of set 7 | celestun
# Processing record 40 of set 7 | agadez
# Processing record 41 of set 7 | montepuez
# Processing record 42 of set 7 | darnah
# Processing record 43 of set 7 | flin flon
# Processing record 44 of set 7 | cabo san lucas
# City not found in OpenWeather API.
# Processing record 45 of set 7 | boddam
# Processing record 46 of set 7 | kyabe
# Processing record 47 of set 7 | baker city
# Processing record 48 of set 7 | namibe
# Processing record 49 of set 7 | hay river
# Processing record 50 of set 7 | bani
# Processing record 1 of set 8 | luderitz
# Processing record 2 of set 8 | tapejara
# Processing record 3 of set 8 | anshun
# Processing record 4 of set 8 | kavieng
# Processing record 5 of set 8 | maarianhamina
# Processing record 6 of set 8 | balkanabat
# Processing record 7 of set 8 | paamiut
# Processing record 8 of set 8 | waingapu
# Processing record 9 of set 8 | millerovo
# Processing record 10 of set 8 | severodvinsk
# Processing record 11 of set 8 | lhokseumawe
# Processing record 12 of set 8 | plouzane
# Processing record 13 of set 8 | aksu
# Processing record 14 of set 8 | ilebo
# Processing record 15 of set 8 | gornyy
# Processing record 16 of set 8 | richards bay
# Processing record 17 of set 8 | formosa
# Processing record 18 of set 8 | do gonbadan
# Processing record 19 of set 8 | zaraza
# City not found in OpenWeather API.
# Processing record 20 of set 8 | brazzaville
# Processing record 21 of set 8 | ilulissat
# Processing record 22 of set 8 | odweyne
# Processing record 23 of set 8 | diego de almagro
# Processing record 24 of set 8 | yellowknife
# Processing record 25 of set 8 | itarema
# Processing record 26 of set 8 | sur
# Processing record 27 of set 8 | diffa
# Processing record 28 of set 8 | bowen
# Processing record 29 of set 8 | goldsboro
# Processing record 30 of set 8 | gobabis
# Processing record 31 of set 8 | banon
# Processing record 32 of set 8 | bekhtery
# Processing record 33 of set 8 | whitehorse
# Processing record 34 of set 8 | ankang
# Processing record 35 of set 8 | margate
# Processing record 36 of set 8 | leshukonskoye
# Processing record 37 of set 8 | vestmannaeyjar
# Processing record 38 of set 8 | gejiu
# Processing record 39 of set 8 | tamworth
# Processing record 40 of set 8 | deputatskiy
# Processing record 41 of set 8 | necochea
# Processing record 42 of set 8 | fallon
# Processing record 43 of set 8 | shimoda
# Processing record 44 of set 8 | donaueschingen
# Processing record 45 of set 8 | wasilla
# Processing record 46 of set 8 | qaqortoq
# Processing record 47 of set 8 | klyuchi
# Processing record 48 of set 8 | sangueya
# Processing record 49 of set 8 | eyl
# Processing record 50 of set 8 | osakarovka
# Processing record 1 of set 9 | amuntai
# Processing record 2 of set 9 | atar
# Processing record 3 of set 9 | khonsa
# Processing record 4 of set 9 | williams lake
# City not found in OpenWeather API.
# Processing record 5 of set 9 | makanya
# Processing record 6 of set 9 | betare oya
# Processing record 7 of set 9 | hauterive
# Processing record 8 of set 9 | kahama
# Processing record 9 of set 9 | noshiro
# Processing record 10 of set 9 | svetlaya
# Processing record 11 of set 9 | dolores
# Processing record 12 of set 9 | beyneu
# City not found in OpenWeather API.
# City not found in OpenWeather API.
# Processing record 13 of set 9 | chunhuhub
# City not found in OpenWeather API.
# Processing record 14 of set 9 | hofn
# Processing record 15 of set 9 | alexandroupoli
# Processing record 16 of set 9 | nago
# Processing record 17 of set 9 | north platte
# Processing record 18 of set 9 | divnogorsk
# Processing record 19 of set 9 | mayumba
# Processing record 20 of set 9 | chizhou
# Processing record 21 of set 9 | benguela
# Processing record 22 of set 9 | rovinj
# Processing record 23 of set 9 | abu kamal
# Processing record 24 of set 9 | saint-louis
# Processing record 25 of set 9 | hit
# Processing record 26 of set 9 | sao jose da coroa grande
# Processing record 27 of set 9 | balabac
# Processing record 28 of set 9 | ijevan
# Processing record 29 of set 9 | mount isa
# City not found in OpenWeather API.
# City not found in OpenWeather API.
# Processing record 30 of set 9 | chapleau
# Processing record 31 of set 9 | faisalabad
# City not found in OpenWeather API.
# Processing record 32 of set 9 | hambantota
# Processing record 33 of set 9 | ca mau
# Processing record 34 of set 9 | huilong
# Processing record 35 of set 9 | samarai
# Processing record 36 of set 9 | powell river
# Processing record 37 of set 9 | san quintin
# Processing record 38 of set 9 | airai
# Processing record 39 of set 9 | beira
# Processing record 40 of set 9 | storforshei
# Processing record 41 of set 9 | epping
# Processing record 42 of set 9 | columbia
# Processing record 43 of set 9 | kupang
# Processing record 44 of set 9 | matai
# Processing record 45 of set 9 | tomatlan
# Processing record 46 of set 9 | kemijarvi
# Processing record 47 of set 9 | bonavista
# Processing record 48 of set 9 | pampa
# Processing record 49 of set 9 | mareeba
# Processing record 50 of set 9 | petukhovo
# City not found in OpenWeather API.
# Processing record 1 of set 10 | bhopal
# Processing record 2 of set 10 | praia da vitoria
# Processing record 3 of set 10 | chala
# Processing record 4 of set 10 | maldonado
# Processing record 5 of set 10 | meoqui
# Processing record 6 of set 10 | shakawe
# Processing record 7 of set 10 | prince rupert
# Processing record 8 of set 10 | khorixas
# Processing record 9 of set 10 | puerto ayacucho
# Processing record 10 of set 10 | red bluff
# Processing record 11 of set 10 | ostrovnoy
# City not found in OpenWeather API.
# City not found in OpenWeather API.
# Processing record 12 of set 10 | manggar
# Processing record 13 of set 10 | umm kaddadah
# Processing record 14 of set 10 | nakamura
# City not found in OpenWeather API.
# City not found in OpenWeather API.
# Processing record 15 of set 10 | san carlos de bariloche
# Processing record 16 of set 10 | sao felix do xingu
# Processing record 17 of set 10 | medicine hat
# Processing record 18 of set 10 | mangaratiba
# Processing record 19 of set 10 | lasa
# Processing record 20 of set 10 | doha
# Processing record 21 of set 10 | jinchang
# Processing record 22 of set 10 | champerico
# Processing record 23 of set 10 | san andres
# City not found in OpenWeather API.
# Processing record 24 of set 10 | half moon bay
# City not found in OpenWeather API.
# Processing record 25 of set 10 | shwebo
# Processing record 26 of set 10 | anadyr
# Processing record 27 of set 10 | belmonte
# Processing record 28 of set 10 | saint-pierre
# Processing record 29 of set 10 | tutoia
# Processing record 30 of set 10 | olden
# Processing record 31 of set 10 | bagdarin
# Processing record 32 of set 10 | chulman
# Processing record 33 of set 10 | bilma
# Processing record 34 of set 10 | jiancheng
# Processing record 35 of set 10 | lubango
# Processing record 36 of set 10 | concarneau
# Processing record 37 of set 10 | gat
# Processing record 38 of set 10 | banjarmasin
# Processing record 39 of set 10 | moron
# Processing record 40 of set 10 | thurso
# Processing record 41 of set 10 | anamur
# Processing record 42 of set 10 | poso
# Processing record 43 of set 10 | katobu
# Processing record 44 of set 10 | dharchula
# Processing record 45 of set 10 | petropavlovsk-kamchatskiy
# Processing record 46 of set 10 | brownsville
# Processing record 47 of set 10 | tambura
# Processing record 48 of set 10 | manokwari
# Processing record 49 of set 10 | sayyan
# Processing record 50 of set 10 | ukiah
# Processing record 1 of set 11 | lucea
# Processing record 2 of set 11 | port macquarie
# Processing record 3 of set 11 | avallon
# Processing record 4 of set 11 | mehriz
# Processing record 5 of set 11 | bandarbeyla
# Processing record 6 of set 11 | saint anthony
# Processing record 7 of set 11 | gayny
# Processing record 8 of set 11 | dezful
# Processing record 9 of set 11 | los llanos de aridane
# Processing record 10 of set 11 | filadelfia
# Processing record 11 of set 11 | lorengau
# City not found in OpenWeather API.
# Processing record 12 of set 11 | nyurba
# Processing record 13 of set 11 | grand gaube
# Processing record 14 of set 11 | hongjiang
# Processing record 15 of set 11 | saint-joseph
# Processing record 16 of set 11 | andenes
# Processing record 17 of set 11 | mapiripan
# Processing record 18 of set 11 | labuhan
# Processing record 19 of set 11 | nangong
# Processing record 20 of set 11 | coquimbo
# Processing record 21 of set 11 | ormara
# Processing record 22 of set 11 | vakhrushev
# Processing record 23 of set 11 | sepuka
# Processing record 24 of set 11 | pueblo
# Processing record 25 of set 11 | bermejo
# City not found in OpenWeather API.
# City not found in OpenWeather API.
# Processing record 26 of set 11 | moose factory
# Processing record 27 of set 11 | burnie
# Processing record 28 of set 11 | ahipara
# Processing record 29 of set 11 | salsk
# Processing record 30 of set 11 | vila velha
# Processing record 31 of set 11 | ust-koksa
# Processing record 32 of set 11 | nuqui
# Processing record 33 of set 11 | tonami
# Processing record 34 of set 11 | dauphin
# Processing record 35 of set 11 | chongwe
# Processing record 36 of set 11 | pindiga
# Processing record 37 of set 11 | kisanga
# Processing record 38 of set 11 | chincha alta
# Processing record 39 of set 11 | ust-shonosha
# Processing record 40 of set 11 | singkawang
# Processing record 41 of set 11 | arman
# Processing record 42 of set 11 | halifax
# Processing record 43 of set 11 | annau
# Processing record 44 of set 11 | koslan
# Processing record 45 of set 11 | korla
# Processing record 46 of set 11 | presidencia roque saenz pena
# Processing record 47 of set 11 | tygda
# Processing record 48 of set 11 | port hardy
# Processing record 49 of set 11 | zhadovka
# City not found in OpenWeather API.
# Processing record 50 of set 11 | manali
# Processing record 1 of set 12 | lethem
# Processing record 2 of set 12 | ketchikan
# Processing record 3 of set 12 | lermontovka
# Processing record 4 of set 12 | zheshart
# Processing record 5 of set 12 | kamenka
# Processing record 6 of set 12 | santa fe
# Processing record 7 of set 12 | caxito
# Processing record 8 of set 12 | mormugao
# Processing record 9 of set 12 | gravdal
# Processing record 10 of set 12 | bintulu
# Processing record 11 of set 12 | naryan-mar
# Processing record 12 of set 12 | antequera
# Processing record 13 of set 12 | timmins
# Processing record 14 of set 12 | kotelnich
# Processing record 15 of set 12 | pulandian
# Processing record 16 of set 12 | nusaybin
# Processing record 17 of set 12 | el higo
# Processing record 18 of set 12 | byron bay

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create original data frame for the weather data from the generated lists
weather_data_dict={'City':city_list_500,
                      'Latitude':lat_500,
                      'Longitude':long_500,
                      'Max Temp':max_temp_500,
                      'Humidity':humidity_500,
                      'Cloudiness':cloudiness_500,
                      'Wind Speed':wind_speed_500,
                      'Country':country_500,
                      'Date':date_500
                     }

weather_0_df=pd.DataFrame(weather_data_dict)
weather_0_df.head()
# Out:
#           City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0  Letterkenny   54.9500    -7.7333    274.06        88         100
# 1        Kapaa   22.0752  -159.3190    299.15        65          75
# 2     Seymchan   62.8833   152.4333    239.40        80         100
# 3   Phan Thiet   10.9333   108.1000    295.04        72         100
# 4    Tuatapere  -46.1333   167.6833    291.85        47          93
#
#    Wind Speed Country        Date
# 0        4.16      IE  1612052820
# 1        6.69      US  1612052817
# 2        4.77      RU  1612052821
# 3        2.17      VN  1612052821
# 4        0.59      NZ  1612052821

# %%
#Print a describe table for the weather data frame
weather_0_df.describe()
# Out:
#          Latitude   Longitude    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  568.000000  568.000000  568.000000  568.000000  568.000000  568.000000
# mean    19.716088   21.003035  282.301849   74.262324   55.271127    3.583838
# std     33.654980   90.627306   18.157528   18.623813   39.141768    2.561657
# min    -54.800000 -175.200000  228.020000   10.000000    0.000000    0.040000
# 25%     -8.341675  -58.649050  271.097500   65.000000   13.750000    1.555000
# 50%     24.216650   27.517950  288.815000   79.000000   75.000000    3.080000
# 75%     48.657925  105.318250  297.010000   88.000000   92.000000    5.140000
# max     78.218600  179.316700  308.150000  100.000000  100.000000   14.920000
#
#                Date
# count  5.680000e+02
# mean   1.612053e+09
# std    8.708811e+01
# min    1.612052e+09
# 25%    1.612053e+09
# 50%    1.612053e+09
# 75%    1.612053e+09
# max    1.612053e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#Filter out cities with humidities great than 100%
#weather_1_df applies the humidy filter to weather_0_df
humidity_filter=weather_0_df.loc[:,'Humidity']<=100
weather_1_df=weather_0_df.loc[humidity_filter,:]
weather_1_df.head()
# Out:
#           City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0  Letterkenny   54.9500    -7.7333    274.06        88         100
# 1        Kapaa   22.0752  -159.3190    299.15        65          75
# 2     Seymchan   62.8833   152.4333    239.40        80         100
# 3   Phan Thiet   10.9333   108.1000    295.04        72         100
# 4    Tuatapere  -46.1333   167.6833    291.85        47          93
#
#    Wind Speed Country        Date
# 0        4.16      IE  1612052820
# 1        6.69      US  1612052817
# 2        4.77      RU  1612052821
# 3        2.17      VN  1612052821
# 4        0.59      NZ  1612052821

# %%
weather_1_df.describe()
# Out:
#          Latitude   Longitude    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  568.000000  568.000000  568.000000  568.000000  568.000000  568.000000
# mean    19.716088   21.003035  282.301849   74.262324   55.271127    3.583838
# std     33.654980   90.627306   18.157528   18.623813   39.141768    2.561657
# min    -54.800000 -175.200000  228.020000   10.000000    0.000000    0.040000
# 25%     -8.341675  -58.649050  271.097500   65.000000   13.750000    1.555000
# 50%     24.216650   27.517950  288.815000   79.000000   75.000000    3.080000
# 75%     48.657925  105.318250  297.010000   88.000000   92.000000    5.140000
# max     78.218600  179.316700  308.150000  100.000000  100.000000   14.920000
#
#                Date
# count  5.680000e+02
# mean   1.612053e+09
# std    8.708811e+01
# min    1.612052e+09
# 25%    1.612053e+09
# 50%    1.612053e+09
# 75%    1.612053e+09
# max    1.612053e+09

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_over_filter=weather_0_df.loc[:,'Humidity']>100
weather_over_df=weather_0_df.loc[humidity_over_filter,:]
list(weather_over_df.index)
weather_over_df.index
# Out:
# Int64Index([], dtype='int64')

# %%
#Export Weather Data Frame to CSV
weather_1_df.to_csv(output_data_file)

# %% [markdown]
# ## Weather Data Scatter Plots
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Scatter plot of max temperature vs latitude for weather data after filtering out cities with humidity >100 
x_lat=weather_1_df['Latitude']
y_maxtemp=weather_1_df['Max Temp']

plt.scatter(x_lat,y_maxtemp)
plt.title('Max Temperature vs. City Latitude')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (K)')
plt.grid(b=True)
plt.savefig('output_data/MaxTemp_Lat_Scatter.png')

print(f'The Max Temperature vs. City Latitude scatter plot visualy displays how the latitude of a city \nimpacts its Maximum Temerature. Based on this relationship, it is clear that the highest Maximum Temperatures \noccur in cities closest to the equator (0 Degreese Latitude).')
# Out:
# The Max Temperature vs. City Latitude scatter plot visualy displays how the latitude of a city
# impacts its Maximum Temerature. Based on this relationship, it is clear that the highest Maximum Temperatures
# occur in cities closest to the equator (0 Degreese Latitude).

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Scatter plot of humidity vs latitude for weather data after filtering out cities with humidity >100 
x_lat=weather_1_df['Latitude']
y_humidity=weather_1_df['Humidity']

plt.scatter(x_lat,y_humidity)
plt.title('Humidity vs. City Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(b=True)
plt.savefig('output_data/Humidity_Lat_Scatter.png')

print(f'The Humidity vs. City Latitude scatter plot visualy displays how the latitude of a city \nimpacts its Humidity level. There does not appear to be an obvious trend between the two variables.')
# Out:
# The Humidity vs. City Latitude scatter plot visualy displays how the latitude of a city
# impacts its Humidity level. There does not appear to be an obvious trend between the two variables.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Scatter plot of cloudiness vs latitude for weather data after filtering out cities with humidity >100 
x_lat=weather_1_df['Latitude']
y_cloudiness=weather_1_df['Cloudiness']

plt.scatter(x_lat,y_cloudiness)
plt.title('Cloudiness vs. City Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(b=True)
plt.savefig('output_data/Cloudiness_Lat_Scatter.png')

print(f'The Cloudiness vs. City Latitude scatter plot visualy displays how the latitude of a city \nimpacts its Cloudiness level. There does not appear to be an obvious trend between the two variables.')
# Out:
# The Cloudiness vs. City Latitude scatter plot visualy displays how the latitude of a city
# impacts its Cloudiness level. There does not appear to be an obvious trend between the two variables.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Scatter plot of wind speed vs latitude for weather data after filtering out cities with humidity >100 
x_lat=weather_1_df['Latitude']
y_windspeed=weather_1_df['Wind Speed']

plt.scatter(x_lat,y_windspeed)
plt.title('City Latitude vs Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid(b=True)
plt.savefig('output_data/WindSpeed_Lat_Scatter.png')

print(f'The Wind Speed vs. City Latitude scatter plot visualy displays how the latitude of a city \nimpacts its Wind Speed. There does not appear to be an obvious trend between the two variables.')
# Out:
# The Wind Speed vs. City Latitude scatter plot visualy displays how the latitude of a city
# impacts its Wind Speed. There does not appear to be an obvious trend between the two variables.

# %% [markdown]
# ## Linear Regressions by Hemisphere

# %%
#Northern Hemisphere Filter (Latitude>=0), assume that the equator is grouped into Norther Hemisphere
#weather_2_df includes only cities in the norther hemisphere
northern_filter=weather_1_df.loc[:,'Latitude']>=0
weather_2_df=weather_1_df.loc[northern_filter,:]
weather_2_df.head()
# Out:
#           City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0  Letterkenny   54.9500    -7.7333    274.06        88         100
# 1        Kapaa   22.0752  -159.3190    299.15        65          75
# 2     Seymchan   62.8833   152.4333    239.40        80         100
# 3   Phan Thiet   10.9333   108.1000    295.04        72         100
# 5    Jamestown   42.0970   -79.2353    265.15        86           1
#
#    Wind Speed Country        Date
# 0        4.16      IE  1612052820
# 1        6.69      US  1612052817
# 2        4.77      RU  1612052821
# 3        2.17      VN  1612052821
# 5        1.54      US  1612052673

# %%
#Souther Hemisphere Filter (Latitude<0)
#weather_3_df includes only cities in the southern hemisphere
southern_filter=weather_1_df.loc[:,'Latitude']<0
weather_3_df=weather_1_df.loc[southern_filter,:]
weather_3_df.head()
# Out:
#                City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 4         Tuatapere  -46.1333   167.6833    291.85        47          93
# 6            Castro  -24.7911   -50.0119    291.92        98         100
# 8          Bengkulu   -3.8004   102.2655    297.06        94          98
# 10       Kaitangata  -46.2817   169.8464    289.26        80          72
# 12  Arraial do Cabo  -22.9661   -42.0278    298.33        80          39
#
#     Wind Speed Country        Date
# 4         0.59      NZ  1612052821
# 6         1.61      BR  1612052821
# 8         4.02      ID  1612052805
# 10        5.81      NZ  1612052822
# 12       12.46      BR  1612052822

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Norther Hemisphere max temperature vs latitude for weather data after filtering out cities with humidity >100 
#Linear Regression

x_lat=weather_2_df['Latitude']
y_maxtemp=weather_2_df['Max Temp']
                                   
plt.scatter(x_lat,y_maxtemp)
plt.title('Norther Hemisphere: Max Temperature vs. City Latitude')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (K)')
plt.grid(b=True)
plt.xlim(0,90)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_lat, y_maxtemp)
regress_values = x_lat * slope + intercept
line_eq = f'y = {round(slope,2)}x + {round(intercept,2)}'
plt.plot(x_lat,regress_values,"r-")
plt.annotate(line_eq,(50,300),fontsize=15,color="red")
plt.annotate(f'r-value={round(rvalue,2)}',(50,290),fontsize=15,color="red")

plt.savefig('output_data/Norther_MaxTemp_Lat_Reg.png')

northern_equator_temp=intercept

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#SOuthern Hemisphere max temperature vs latitude for weather data after filtering out cities with humidity >100 
#Linear Regression

x_lat=weather_3_df['Latitude']
y_maxtemp=weather_3_df['Max Temp']
                                            
plt.scatter(x_lat,y_maxtemp)
plt.title('Southern Hemisphere: Max Temperature vs. City Latitude')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (K)')
plt.grid(b=True)
plt.xlim(-90,0)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_lat, y_maxtemp)
regress_values = x_lat * slope + intercept
line_eq = f'y = {round(slope,2)}x + {round(intercept,2)}'
plt.plot(x_lat,regress_values,"r-")
plt.annotate(line_eq,(-85,300),fontsize=15,color="red")
plt.annotate(f'r-value={round(rvalue,2)}',(-85,297),fontsize=15,color="red")

plt.savefig('output_data/Southern_MaxTemp_Lat_Reg.png')

southern_equator_temp=intercept

# %%
#Analysis of Latitude of Max Temperature vs. Latitude for the Northern and Southern Hemospheres
print(f'Based on the Max Temperature vs. Latitude regression for the Northern and Southern Hemispheres,\nthe expected temperatures at the equator are {round(northern_equator_temp,2)} K and {round(southern_equator_temp,2)} K respectively.\nCombining these two results together, the Max Temperature near the equator is likely close to {round((northern_equator_temp+southern_equator_temp)/2,2)} K.')
# Out:
# Based on the Max Temperature vs. Latitude regression for the Northern and Southern Hemispheres,
# the expected temperatures at the equator are 306.11 K and 299.46 K respectively.
# Combining these two results together, the Max Temperature near the equator is likely close to 302.78 K.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Norther Hemisphere max temperature vs latitude for weather data after filtering out cities with humidity >100 
#Linear Regression

x_lat=weather_2_df['Latitude']
y_humidity=weather_2_df['Humidity']
                                          
plt.scatter(x_lat,y_humidity)
plt.title('Norther Hemisphere: Humidity vs. City Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(b=True)
plt.xlim(0,90)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_lat, y_humidity)
regress_values = x_lat * slope + intercept
line_eq = f'y = {round(slope,2)}x + {round(intercept,2)}'
plt.plot(x_lat,regress_values,"r-")
plt.annotate(line_eq,(50,50),fontsize=15,color="red")
plt.annotate(f'r-value={round(rvalue,2)}',(50,40),fontsize=15,color="red")
plt.savefig('output_data/Northern_Humidity_Lat_Reg.png')

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Southern Hemisphere humidity vs latitude for weather data after filtering out cities with humidity >100 
#Linear Regression

x_lat=weather_3_df['Latitude']
y_humidity=weather_3_df['Humidity']
                                          
plt.scatter(x_lat,y_humidity)
plt.title('Southern Hemisphere: Humidity vs. City Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(b=True)
plt.xlim(-90,0)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_lat, y_humidity)
regress_values = x_lat * slope + intercept
line_eq = f'y = {round(slope,2)}x + {round(intercept,2)}'
plt.plot(x_lat,regress_values,"r-")
plt.annotate(line_eq,(-80,35),fontsize=15,color="red")
plt.annotate(f'r-value={round(rvalue,2)}',(-80,25),fontsize=15,color="red")
plt.savefig('output_data/Southern_Humidity_Lat_Reg.png')

# %%
#Analysis of Humidity vs. Latitude for the Northern and Southern Hemospheres
print(f'Based on the Humidity vs. Latitude regression for the Northern and Southern Hemispheres,\n there does not appear to be a strong relationship between the two variables for either hemisphere.\nTheoretically, humidity is a function of the air temperature and the the moisture available to be absorbed.')
# Out:
# Based on the Humidity vs. Latitude regression for the Northern and Southern Hemispheres,
#  there does not appear to be a strong relationship between the two variables for either hemisphere.
# Theoretically, humidity is a function of the air temperature and the the moisture available to be absorbed.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Norther Hemisphere cloudiness vs latitude for weather data after filtering out cities with humidity >100 
#Linear Regression

x_lat=weather_2_df['Latitude']
y_cloudiness=weather_2_df['Cloudiness']
                                          
plt.scatter(x_lat,y_cloudiness)
plt.title('Norther Hemisphere: Cloudiness vs. City Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(b=True)
plt.xlim(0,90)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_lat, y_cloudiness)
regress_values = x_lat * slope + intercept
line_eq = f'y = {round(slope,2)}x + {round(intercept,2)}'
plt.plot(x_lat,regress_values,"r-")
plt.annotate(line_eq,(50,30),fontsize=15,color="red")
plt.annotate(f'r-value={round(rvalue,2)}',(50,20),fontsize=15,color="red")
plt.savefig('output_data/Northern_Cloudiness_Lat_Reg.png')

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Southern Hemisphere cloudiness vs latitude for weather data after filtering out cities with humidity >100 
#Linear Regression

x_lat=weather_3_df['Latitude']
y_cloudiness=weather_3_df['Cloudiness']
                                          
plt.scatter(x_lat,y_cloudiness)
plt.title('Southern Hemisphere: Cloudiness vs. City Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(b=True)
plt.xlim(-90,0)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_lat, y_cloudiness)
regress_values = x_lat * slope + intercept
line_eq = f'y = {round(slope,2)}x + {round(intercept,2)}'
plt.plot(x_lat,regress_values,"r-")
plt.annotate(line_eq,(-80,25),fontsize=15,color="red")
plt.annotate(f'r-value={round(rvalue,2)}',(-80,15),fontsize=15,color="red")
plt.savefig('output_data/Southern_Cloudiness_Lat_Reg.png')

# %%
#Analysis of Cloudiness vs. Latitude for the Northern and Southern Hemospheres
print(f'Based on the Cloudiness vs. Latitude regression for the Northern and Southern Hemispheres,\nthere does not appear to be a strong correlation between the two variables for either hemisphere. ')
# Out:
# Based on the Cloudiness vs. Latitude regression for the Northern and Southern Hemispheres,
# there does not appear to be a strong correlation between the two variables for either hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Norther Hemisphere Wind Speed vs latitude for weather data after filtering out cities with humidity >100 
#Linear Regression

x_lat=weather_2_df['Latitude']
y_windspeed=weather_2_df['Wind Speed']
                                          
plt.scatter(x_lat,y_windspeed)
plt.title('Norther Hemisphere: Wind Speed vs. City Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid(b=True)
plt.xlim(0,90)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_lat, y_windspeed)
regress_values = x_lat * slope + intercept
line_eq = f'y = {round(slope,2)}x + {round(intercept,2)}'
plt.plot(x_lat,regress_values,"r-")
plt.annotate(line_eq,(50,16),fontsize=15,color="red")
plt.annotate(f'r-value={round(rvalue,2)}',(50,14),fontsize=15,color="red")
plt.savefig('output_data/Northern_WindSpeed_Lat_Reg.png')

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Southern Hemisphere Wind Speed vs latitude for weather data after filtering out cities with humidity >100 
#Linear Regression

x_lat=weather_3_df['Latitude']
y_windspeed=weather_3_df['Wind Speed']
                                          
plt.scatter(x_lat,y_windspeed)
plt.title('Southern Hemisphere: Wind Speed vs. City Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid(b=True)
plt.xlim(-90,0)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_lat, y_windspeed)
regress_values = x_lat * slope + intercept
line_eq = f'y = {round(slope,2)}x + {round(intercept,2)}'
plt.plot(x_lat,regress_values,"r-")
plt.annotate(line_eq,(-80,7),fontsize=15,color="red")
plt.annotate(f'r-value={round(rvalue,2)}',(-80,6),fontsize=15,color="red")
plt.savefig('output_data/Southern_WindSpeed_Lat_Reg.png')

# %%
#Analysis of Wind Speed vs. Latitude for the Northern and Southern Hemospheres
print(f'Based on the Wind Speed vs. Latitude regression for the Northern and Southern Hemispheres,\nthere does not appear to be a strong correlation between the two variables for either hemisphere.')
# Out:
# Based on the Wind Speed vs. Latitude regression for the Northern and Southern Hemispheres,
# there does not appear to be a strong correlation between the two variables for either hemisphere.
